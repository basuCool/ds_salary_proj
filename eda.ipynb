# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\builds\\ML\\DS_salary_project\\Salary_data_cleaned_full.csv")

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\r\nLocation: Albuquerque, NM\r\...     3.8
# 1  What You Will Do:\r\n\r\nI. General Summary\r\...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\r\nJob ID: 310709\r...     3.8
# 4  Data Scientist\r\nAffinity Solutions / Marketi...     2.9
#
#                                    Company Name         Location  \
# 0                      Tecolote Research\r\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\r\n3.4    Linthicum, MD
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'comp_text', 'job_state', 'same_state', 'age_comp',
#        'python', 'R_studio', 'Spark', 'aws', 'excel', 'job_simp',
#        'job_seniority', 'desc_len', 'competitors_count'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  662.000000   662.000000  662.000000         662.000000  662.000000
# mean     3.631571  1841.951662    0.030211           0.021148   74.389728
# std      0.805757   488.940326    0.171298           0.143987   31.910414
# min     -1.000000    -1.000000    0.000000           0.000000   10.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.500000    0.000000           0.000000   70.000000
# 75%      4.000000  2007.000000    0.000000           0.000000   92.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  average_salary  same_state    age_comp      python  \
# count  662.000000      662.000000  662.000000  662.000000  662.000000
# mean   127.503021      101.750665    0.561934   47.645015    0.534743
# std     46.772043       37.495205    0.496525   54.111802    0.499169
# ...

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.average_salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.age_comp.hist()
# Out:
# <AxesSubplot:>

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['age_comp','average_salary','Rating'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'Rating')
# Out:
# <AxesSubplot:>

# %%
df[['age_comp','average_salary','Rating','desc_len','competitors_count']].corr()
# Out:
#                    age_comp  average_salary    Rating  desc_len  \
# age_comp           1.000000        0.014438  0.011905  0.138870
# average_salary     0.014438        1.000000  0.009531  0.059651
# Rating             0.011905        0.009531  1.000000 -0.019805
# desc_len           0.138870        0.059651 -0.019805  1.000000
# competitors_count  0.121689        0.065576  0.024674  0.093098
#
#                    competitors_count
# age_comp                    0.121689
# average_salary              0.065576
# Rating                      0.024674
# desc_len                    0.093098
# competitors_count           1.000000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'comp_text', 'job_state', 'same_state', 'age_comp',
#        'python', 'R_studio', 'Spark', 'aws', 'excel', 'job_simp',
#        'job_seniority', 'desc_len', 'competitors_count'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue','comp_text','job_state','same_state','python', 'R_studio', 'Spark', 'aws', 'excel', 'job_simp',
       'job_seniority']]

# %%
for i in df_cat.columns:
    cat_num=df_cat[i].value_counts()
    print("graph for %s: total = %d" %(i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# graph for Location: total = 197
# graph for Headquarters: total = 195
# graph for Size: total = 9
# graph for Type of ownership: total = 11
# graph for Industry: total = 60
# graph for Sector: total = 25
# graph for Revenue: total = 14
# graph for comp_text: total = 335
# graph for job_state: total = 37
# graph for same_state: total = 2
# graph for python: total = 2
# graph for R_studio: total = 2
# graph for Spark: total = 2
# graph for aws: total = 2
# graph for excel: total = 2
# graph for job_simp: total = 7
# graph for job_seniority: total = 3

# %%
for i in df_cat[['Location', 'Headquarters','comp_text']].columns:
    cat_num=df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" %(i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for comp_text: total = 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'comp_text', 'job_state', 'same_state', 'age_comp',
#        'python', 'R_studio', 'Spark', 'aws', 'excel', 'job_simp',
#        'job_seniority', 'desc_len', 'competitors_count'],
#       dtype='object')

# %%
pd.pivot_table(df, index = ['job_simp','job_seniority'], values = 'average_salary')
# Out:
#                               average_salary
# job_simp       job_seniority
# analyst        jr                  53.250000
#                na                  61.560606
#                senior              79.166400
# data engineer  na                  96.472603
#                senior             126.712121
# data scientist na                 107.590909
#                senior             138.641975
# director       na                 162.038462
# manager        na                  84.833333
# mle            na                 122.000000
#                senior             145.083333
# na             na                  78.484220
#                senior             110.364583

# %%
pd.pivot_table(df, index = ['job_state','job_simp'],values = 'average_salary').sort_values('job_state',ascending=False)
# Out:
#                           average_salary
# job_state job_simp
#  WI       na                   54.000000
#           data scientist      113.500000
#           analyst              58.833333
#  WA       na                   97.500000
#           data scientist      100.437500
# ...                                  ...
#  AZ       analyst              55.000000
#           na                  124.500000
#  AL       na                   43.750000
#           data engineer        65.000000
#           analyst              62.200000
#
# [113 rows x 1 columns]

# %%
pd.set_option('display.max_rows', None)
pd.pivot_table(df, index = ['job_state','job_simp'],values = 'average_salary', aggfunc='count').sort_values('job_state',ascending=False)
# Out:
#                           average_salary
# job_state job_simp
#  WI       na                           3
#           data scientist               3
#           analyst                      3
#  WA       na                           1
#           data scientist              16
#           analyst                      3
#  VA       na                           4
#           mle                          2
#           data scientist              16
#           data engineer               10
#           analyst                      6
#  UT       data engineer                3
#           analyst                      3
#           data scientist               3
#  TX       na                           6
#           data scientist              13
#           data engineer                7
#  TN       data scientist               1
#           data engineer                7
#           analyst                      2
#  SC       na                           1
# ...

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index = 'job_state',values = 'average_salary').sort_values('average_salary',ascending=False)
# Out:
#            average_salary
# job_state
#  DC            162.125000
#  CA            142.023810
#  UT            140.500000
#  MO            127.666667
#  NC            117.000000
#  NY            116.000000
#  IL            114.615385
#  MA            114.410714
#  WI            113.500000
#  PA            110.300000
#  CO            108.666667
#  VA            108.312500
#  NJ            106.875000
#  MD            106.541667
#  OH            105.000000
#  TX            100.730769
#  WA            100.437500
#  MI             98.833333
#  OR             98.500000
#  FL             97.357143
#  TN             96.000000
#  IN             84.500000
#  KY             84.000000
#  CT             84.000000
#  GA             81.333333
#  NM             74.333333

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'comp_text', 'job_state', 'same_state', 'age_comp',
#        'python', 'R_studio', 'Spark', 'aws', 'excel', 'job_simp',
#        'job_seniority', 'desc_len', 'competitors_count'],
#       dtype='object')

# %%
df_pivots=df[['Rating','Type of ownership', 'Industry', 'Sector', 'Revenue','competitors_count','hourly', 'employer_provided','python', 'R_studio', 'Spark', 'aws', 'excel','average_salary']]

# %%
df_pivots.describe()
# Out:
#            Rating  competitors_count      hourly  employer_provided  \
# count  662.000000         662.000000  662.000000         662.000000
# mean     3.631571           1.052870    0.030211           0.021148
# std      0.805757           1.384565    0.171298           0.143987
# min     -1.000000           0.000000    0.000000           0.000000
# 25%      3.300000           0.000000    0.000000           0.000000
# 50%      3.700000           0.000000    0.000000           0.000000
# 75%      4.000000           3.000000    0.000000           0.000000
# max      5.000000           4.000000    1.000000           1.000000
#
#            python    R_studio       Spark         aws       excel  \
# count  662.000000  662.000000  662.000000  662.000000  662.000000
# mean     0.534743    0.001511    0.231118    0.231118    0.522659
# std      0.499169    0.038866    0.421866    0.421866    0.499864
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index = i, values = 'average_salary').sort_values('average_salary', ascending=False))
# Out:
# Rating
#         average_salary
# Rating
# -1.0        137.800000
#  5.0        135.875000
#  2.5        120.000000
#  4.5        116.916667
#  4.1        116.666667
#  3.9        114.179245
#  2.6        110.055556
#  4.0        108.301429
#  4.4        107.120690
#  3.7        105.715000
#  3.5        105.522222
#  3.2        104.037037
#  4.7        103.983871
#  3.3        103.712941
#  4.2        103.166667
#  4.3        102.413793
#  3.8         97.973448
#  2.2         97.750000
#  4.6         97.250000
#  3.4         93.542105
#  3.6         92.067805
#  2.1         92.000000
#  3.0         87.966667
#  1.9         87.500000
#  2.7         85.666154
#  2.8         83.928571
#  3.1         83.386364
#  4.8         82.625000
#  2.9         82.500000
#  2.3         81.500000
#  2.4         59.700000
# Type of ownership
#                                 average_salary
# Type of ownership
# -1                                  117.500000
# ...

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python', values ='average_salary', aggfunc = 'count' )
# Out:
# python                               0     1
# Revenue
# $1 to $2 billion (USD)            15.0  38.0
# $1 to $5 million (USD)             1.0   7.0
# $10 to $25 million (USD)          15.0  15.0
# $10+ billion (USD)                59.0  51.0
# $100 to $500 million (USD)        41.0  41.0
# $2 to $5 billion (USD)            15.0  21.0
# $25 to $50 million (USD)          20.0  14.0
# $5 to $10 billion (USD)            8.0   9.0
# $5 to $10 million (USD)            7.0   8.0
# $50 to $100 million (USD)         19.0  22.0
# $500 million to $1 billion (USD)  26.0  26.0
# -1                                 1.0   NaN
# Less than $1 million (USD)         1.0   3.0
# Unknown / Non-Applicable          80.0  99.0
